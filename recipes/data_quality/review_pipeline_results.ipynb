# %%
import kmds
from kmds.tagging.tag_types import DataRepresentationTags
from owlready2 import *
from kmds.utils.load_utils import *
KNOWLEDGE_BASE = "ITSM_Raw_Data_Profile.xml"
onto2 :Ontology = load_kb(KNOWLEDGE_BASE)
import pandas as pd
pd.options.display.max_colwidth = 250

# %%
from IPython.display import display
display(load_exp_observations(onto2))
# Out:
#                     obs_type                                         finding  \
# 0   Data Quality Observation      column reassignment_count is of type int64
# 1   Data Quality Observation         sys_created_by has 53076 missing values
# 2   Data Quality Observation         column sys_created_at is of type object
# 3   Data Quality Observation                  location has 76 missing values
# 4   Data Quality Observation                   column active is of type bool
# 5   Data Quality Observation               cmdb_ci has 141267 missing values
# 6   Data Quality Observation                 column notify is of type object
# 7   Data Quality Observation                 column number is of type object
# 8   Data Quality Observation              u_symptom has 32964 missing values
# 9   Data Quality Observation               column priority is of type object
# 10  Data Quality Observation              resolved_by has 226 missing values
# 11  Data Quality Observation              subcategory has 111 missing values
# 12  Data Quality Observation           column sys_mod_count is of type int64
# 13  Data Quality Observation         column incident_state is of type object
# 14  Data Quality Observation                column knowledge is of type bool
# 15  Data Quality Observation              column u_symptom is of type object
# 16  Data Quality Observation            column reopen_count is of type int64
# 17  Data Quality Observation            assigned_to has 27496 missing values
# 18  Data Quality Observation            column subcategory is of type object
# 19  Data Quality Observation                 column vendor is of type object
# 20  Data Quality Observation       assignment_group has 14213 missing values
# 21  Data Quality Observation              column caused_by is of type object
# 22  Data Quality Observation            column closed_code is of type object
# 23  Data Quality Observation                vendor has 141468 missing values
# 24  Data Quality Observation              column caller_id is of type object
# 25  Data Quality Observation               column location is of type object
# 26  Data Quality Observation         sys_created_at has 53076 missing values
# 27  Data Quality Observation         column sys_updated_at is of type object
# 28  Data Quality Observation           column contact_type is of type object
# 29  Data Quality Observation         column sys_updated_by is of type object
# 30  Data Quality Observation             column problem_id is of type object
# 31  Data Quality Observation            column assigned_to is of type object
# 32  Data Quality Observation                  category has 78 missing values
# 33  Data Quality Observation            column resolved_by is of type object
# 34  Data Quality Observation                 column made_sla is of type bool
# 35  Data Quality Observation       column assignment_group is of type object
# 36  Data Quality Observation            column resolved_at is of type object
# 37  Data Quality Observation        data file has 141712 rows and 36 columns
# 38  Data Quality Observation                column cmdb_ci is of type object
# 39  Data Quality Observation              column opened_at is of type object
# 40  Data Quality Observation               opened_by has 4835 missing values
# 41  Data Quality Observation              column opened_by is of type object
# 42  Data Quality Observation             caused_by has 141689 missing values
# 43  Data Quality Observation  column u_priority_confirmation is of type bool
# 44  Data Quality Observation                    column rfc is of type object
# 45  Data Quality Observation         column sys_created_by is of type object
# 46  Data Quality Observation                 column impact is of type object
# 47  Data Quality Observation              closed_code has 714 missing values
# 48  Data Quality Observation            problem_id has 139417 missing values
# 49  Data Quality Observation                   rfc has 140721 missing values
# 50  Data Quality Observation               column category is of type object
# 51  Data Quality Observation              column closed_at is of type object
# 52  Data Quality Observation             resolved_at has 3141 missing values
# 53  Data Quality Observation                column urgency is of type object
# 54  Data Quality Observation                 caller_id has 29 missing values
#
#     finding_seq
# 0             5
# 1            40
# 2            13
# 3            42
# 4             4
# 5            46
# 6            29
# 7             2
# 8            45
# 9            24
# 10           54
# 11           44
# 12            7
# 13            3
# 14           27
# 15           20
# 16            6
# 17           48
# 18           19
# 19           32
# 20           47
# 21           33
# 22           34
# 23           51
# 24            9
# 25           17
# 26           41
# 27           15
# 28           16
# 29           14
# 30           30
# 31           26
# 32           43
# 33           35
# 34            8
# 35           25
# 36           36
# 37            1
# 38           21
# 39           11
# 40           39
# 41           10
# 42           52
# 43           28
# 44           31
# 45           12
# 46           22
# 47           53
# 48           49
# 49           50
# 50           18
# 51           37
# 52           55
# 53           23
# 54           38
